# %%
import pandas as pd
import numpy as np

# %%
a = pd.Series(np.arange(12))

# %%
a[0]
# Out:
# 0

# %%
a = pd.Series([3,4,5], index=['a','b','c'])

# %%
a['a']
# Out:
# 3

# %%
a['b']
# Out:
# 4

# %%
dog = pd.read_csv("./data/dogname/dogNames2.csv")

# %%
type(dog)
# Out:
# pandas.core.frame.DataFrame

# %%
dog.describe()
# Out:
#        Count_AnimalName
# count      16220.000000
# mean           6.558631
# std           31.862511
# min            1.000000
# 25%            1.000000
# 50%            1.000000
# 75%            3.000000
# max         1195.000000

# %%
dog[dog['Count_AnimalName'] > 800]
# Out:
#       Row_Labels  Count_AnimalName
# 1156       BELLA              1195
# 2660     CHARLIE               856
# 3251        COCO               852
# 9140         MAX              1153
# 12368      ROCKY               823

# %%
dog.sort_values(by='Count_AnimalName', ascending=False)
# Out:
#            Row_Labels  Count_AnimalName
# 1156            BELLA              1195
# 9140              MAX              1153
# 2660          CHARLIE               856
# 3251             COCO               852
# 12368           ROCKY               823
# 8417             LOLA               795
# 8552            LUCKY               723
# 8560             LUCY               710
# 2032            BUDDY               677
# 3641            DAISY               649
# 11703        PRINCESS               603
# 829            BAILEY               532
# 9766            MOLLY               519
# 14466           TEDDY               485
# 2913            CHLOE               465
# 14779            TOBY               446
# 8620             LUNA               432
# 6515             JACK               425
# 8788           MAGGIE               393
# 13762          SOPHIE               383
# 10750            OREO               383
# 8296             LILY               381
# ...

# %%
# 读取电影数据
movie = pd.read_csv("./data/IMDB/IMDB-Movie-Data.csv")

# %%
movie
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
movie['Rating'].mean()
# Out:
# 6.7231999999999994

# %%
movie['Runtime (Minutes)'].max()
# Out:
# 191

# %%
pd.notnull(movie)
# Out:
#      Rank  Title  Genre  Description  Director  Actors  Year  \
# 0    True   True   True         True      True    True  True
# 1    True   True   True         True      True    True  True
# 2    True   True   True         True      True    True  True
# 3    True   True   True         True      True    True  True
# 4    True   True   True         True      True    True  True
# 5    True   True   True         True      True    True  True
# 6    True   True   True         True      True    True  True
# 7    True   True   True         True      True    True  True
# 8    True   True   True         True      True    True  True
# 9    True   True   True         True      True    True  True
# 10   True   True   True         True      True    True  True
# 11   True   True   True         True      True    True  True
# 12   True   True   True         True      True    True  True
# 13   True   True   True         True      True    True  True
# ...

# %%
movie['Revenue (Millions)'].fillna(movie['Revenue (Millions)'].mean(), inplace=True)

# %%
movie
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
# 如果存在缺失值不是默认np.nan类型的处理方式
data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data")

# %%
data = data.replace(to_replace="?", value=np.nan)

# %%
data
# Out:
#      1000025   5   1  1.1  1.2  2 1.3   3  1.4  1.5  2.1
# 0    1002945   5   4    4    5  7  10   3    2    1    2
# 1    1015425   3   1    1    1  2   2   3    1    1    2
# 2    1016277   6   8    8    1  3   4   3    7    1    2
# 3    1017023   4   1    1    3  2   1   3    1    1    2
# 4    1017122   8  10   10    8  7  10   9    7    1    4
# 5    1018099   1   1    1    1  2  10   3    1    1    2
# 6    1018561   2   1    2    1  2   1   3    1    1    2
# 7    1033078   2   1    1    1  2   1   1    1    5    2
# 8    1033078   4   2    1    1  2   1   2    1    1    2
# 9    1035283   1   1    1    1  1   1   3    1    1    2
# 10   1036172   2   1    1    1  2   1   2    1    1    2
# 11   1041801   5   3    3    3  2   3   4    4    1    4
# 12   1043999   1   1    1    1  2   3   3    1    1    2
# 13   1044572   8   7    5   10  7   9   5    5    4    4
# 14   1047630   7   4    6    4  6   1   4    3    1    4
# ...

# %%
data.dropna()
# Out:
#      1000025   5   1  1.1  1.2  2 1.3   3  1.4  1.5  2.1
# 0    1002945   5   4    4    5  7  10   3    2    1    2
# 1    1015425   3   1    1    1  2   2   3    1    1    2
# 2    1016277   6   8    8    1  3   4   3    7    1    2
# 3    1017023   4   1    1    3  2   1   3    1    1    2
# 4    1017122   8  10   10    8  7  10   9    7    1    4
# 5    1018099   1   1    1    1  2  10   3    1    1    2
# 6    1018561   2   1    2    1  2   1   3    1    1    2
# 7    1033078   2   1    1    1  2   1   1    1    5    2
# 8    1033078   4   2    1    1  2   1   2    1    1    2
# 9    1035283   1   1    1    1  1   1   3    1    1    2
# 10   1036172   2   1    1    1  2   1   2    1    1    2
# 11   1041801   5   3    3    3  2   3   4    4    1    4
# 12   1043999   1   1    1    1  2   3   3    1    1    2
# 13   1044572   8   7    5   10  7   9   5    5    4    4
# 14   1047630   7   4    6    4  6   1   4    3    1    4
# ...

# %%
# 处理时间日期
location = pd.read_csv("./data/FBlocation/train.csv")

# %%
location.head(10)
# Out:
#    row_id       x       y  accuracy    time    place_id
# 0       0  0.7941  9.0809        54  470702  8523065625
# 1       1  5.9567  4.7968        13  186555  1757726713
# 2       2  8.3078  7.0407        74  322648  1137537235
# 3       3  7.3665  2.5165        65  704587  6567393236
# 4       4  4.0961  1.1307        31  472130  7440663949
# 5       5  3.8099  1.9586        75  178065  6289802927
# 6       6  6.3336  4.3720        13  666829  9931249544
# 7       7  5.7409  6.7697        85  369002  5662813655
# 8       8  4.3114  6.9410         3  166384  8471780938
# 9       9  6.3414  0.0758        65  400060  1253803156

# %%
time_value = pd.to_datetime(location['time'], unit='s')

# %%
time_value
# Out:
# 0          1970-01-06 10:45:02
# 1          1970-01-03 03:49:15
# 2          1970-01-04 17:37:28
# 3          1970-01-09 03:43:07
# 4          1970-01-06 11:08:50
# 5          1970-01-03 01:27:45
# 6          1970-01-08 17:13:49
# 7          1970-01-05 06:30:02
# 8          1970-01-02 22:13:04
# 9          1970-01-05 15:07:40
# 10         1970-01-01 05:55:53
# 11         1970-01-02 18:38:13
# 12         1970-01-07 15:34:48
# 13         1970-01-03 18:07:34
# 14         1970-01-04 18:23:31
# 15         1970-01-04 17:18:39
# 16         1970-01-10 00:06:22
# 17         1970-01-04 17:03:53
# 18         1970-01-01 01:44:09
# 19         1970-01-05 18:17:17
# 20         1970-01-09 12:28:33
# 21         1970-01-06 19:01:19
# 22         1970-01-03 02:28:21
# 23         1970-01-09 09:46:43
# 24         1970-01-03 20:08:12
# 25         1970-01-04 17:58:55
# 26         1970-01-04 10:40:23
# 27         1970-01-09 09:58:17
# 28         1970-01-01 03:18:49
# 29         1970-01-04 14:18:54
# ...

# %%
time_value = pd.DatetimeIndex(time_value)

# %%
# 构造列
location['year'] = time_value.year
location['month'] = time_value.month
location['weekday'] = time_value.weekday

# %%
location.head(10)
# Out:
#    row_id       x       y  accuracy    time    place_id  year  month  weekday
# 0       0  0.7941  9.0809        54  470702  8523065625  1970      1        1
# 1       1  5.9567  4.7968        13  186555  1757726713  1970      1        5
# 2       2  8.3078  7.0407        74  322648  1137537235  1970      1        6
# 3       3  7.3665  2.5165        65  704587  6567393236  1970      1        4
# 4       4  4.0961  1.1307        31  472130  7440663949  1970      1        1
# 5       5  3.8099  1.9586        75  178065  6289802927  1970      1        5
# 6       6  6.3336  4.3720        13  666829  9931249544  1970      1        3
# 7       7  5.7409  6.7697        85  369002  5662813655  1970      1        0
# 8       8  4.3114  6.9410         3  166384  8471780938  1970      1        4
# 9       9  6.3414  0.0758        65  400060  1253803156  1970      1        0

# %%
# 商品表的合并，从而进行分析
prior = pd.read_csv("./data/instacart/order_products__prior.csv")

# %%
products = pd.read_csv("./data/instacart/products.csv")

# %%
order = pd.read_csv("./data/instacart/orders.csv")

# %%
aisles = pd.read_csv("./data/instacart/aisles.csv")

# %%
# 合并表
mg = pd.merge(prior, products, on=['product_id', 'product_id'])

# %%
mg = pd.merge(mg, order, on=['order_id', 'order_id'])

# %%
mt = pd.merge(mg, aisles, on=['aisle_id', 'aisle_id'])

# %%
mt.head(10)
# Out:
#    order_id  product_id  add_to_cart_order  reordered        product_name  \
# 0         2       33120                  1          1  Organic Egg Whites
# 1        26       33120                  5          0  Organic Egg Whites
# 2       120       33120                 13          0  Organic Egg Whites
# 3       327       33120                  5          1  Organic Egg Whites
# 4       390       33120                 28          1  Organic Egg Whites
# 5       537       33120                  2          1  Organic Egg Whites
# 6       582       33120                  7          1  Organic Egg Whites
# 7       608       33120                  5          1  Organic Egg Whites
# 8       623       33120                  1          1  Organic Egg Whites
# 9       689       33120                  4          1  Organic Egg Whites
#
#    aisle_id  department_id  user_id eval_set  order_number  order_dow  \
# 0        86             16   202279    prior             3          5
# ...

# %%
# 建立交叉表，分析列之间的关系
table = pd.crosstab(mt['user_id'], mt['aisle'])

# %%
table.head(10)
# Out:
# aisle    air fresheners candles  asian foods  baby accessories  \
# user_id
# 1                             0            0                 0
# 2                             0            3                 0
# 3                             0            0                 0
# 4                             0            0                 0
# 5                             0            2                 0
# 6                             0            0                 0
# 7                             0            0                 0
# 8                             0            1                 0
# 9                             0            0                 0
# 10                            0            1                 0
#
# aisle    baby bath body care  baby food formula  bakery desserts  \
# user_id
# 1                          0                  0                0
# 2                          0                  0                0
# ...

# %%
s = pd.DataFrame({'color': ['white','red','green','red','green'], 'object': ['pen','pencil','pencil','ashtray','pen'],'price1':[5.56,4.20,1.30,0.56,2.75],'price2':[4.75,4.12,1.60,0.75,3.15]})

# %%
a
# Out:
#    color   object  price1  price2
# 0  white      pen    5.56    4.75
# 1    red   pencil    4.20    4.12
# 2  green   pencil    1.30    1.60
# 3    red  ashtray    0.56    0.75
# 4  green      pen    2.75    3.15

# %%
# 如果只是groupy，默认没有去分组，没有去计算
# 1、方式1
a.groupby('color')['price1'].mean()
# Out:
# color
# green    2.025
# red      2.380
# white    5.560
# Name: price1, dtype: float64

# %%
# 2、方式2,数据已经缩小了，不能再选择更多的列
a['price1'].groupby(a['color']).mean()
# Out:
# color
# green    2.025
# red      2.380
# white    5.560
# Name: price1, dtype: float64

# %%
# 读取星巴克的数据
star = pd.read_csv("./data/starbucks/directory.csv")

# %%
star
# Out:
#            Brand  Store Number                           Store Name  \
# 0      Starbucks  47370-257954                        Meritxell, 96
# 1      Starbucks  22331-212325                     Ajman Drive Thru
# 2      Starbucks  47089-256771                            Dana Mall
# 3      Starbucks  22126-218024                           Twofour 54
# 4      Starbucks  17127-178586                         Al Ain Tower
# 5      Starbucks  17688-182164             Dalma Mall, Ground Floor
# 6      Starbucks  18182-182165                  Dalma Mall, Level 1
# 7      Starbucks  23359-229184                   Debenhams Yas Mall
# 8      Starbucks   30781-99022                     Khalidiya Street
# 9      Starbucks  20423-205465                    Eastern Mangroves
# 10     Starbucks  20424-205466                        Nation Towers
# 11     Starbucks   1579-122101  HCT Abu Dhabi Women's College Block
# 12     Starbucks  32595-122105          Standard Chartered Building
# ...

# %%
# 设置新的索引reset_index
country = star.groupby(['Country', 'State/Province']).count()

# %%
country
# Out:
#                         Brand  Store Number  Store Name  Ownership Type  \
# Country State/Province
# AD      7                   1             1           1               1
# AE      AJ                  2             2           2               2
#         AZ                 48            48          48              48
#         DU                 82            82          82              82
#         FU                  2             2           2               2
#         RK                  3             3           3               3
#         SH                  6             6           6               6
#         UQ                  1             1           1               1
# AR      B                  21            21          21              21
#         C                  73            73          73              73
#         M                   5             5           5               5
#         S                   3             3           3               3
# ...
